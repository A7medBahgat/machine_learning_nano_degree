# %%
import sys
import time
from os import listdir
from os.path import isfile, join
import string
import numpy as np
from sklearn.linear_model import LogisticRegression as LR
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import EnglishStemmer
from collections import OrderedDict
import pandas as pd
from nltk.corpus import stopwords

# %%
# imports needed and logging
import gzip
import gensim 
import logging
from gensim.models import Word2Vec
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
def get_file_names(path):
    return [path + "/" + f for f in listdir(path) if isfile(join(path, f))]

# %%
def file_to_tokens(file_name):#, min_word_size, stemmer=None):
    with open(file_name) as f:
        file_string = f.read().rstrip()

        return gensim.utils.simple_preprocess(file_string)
        #return file_string

# %% [markdown]
# ## Train Word Embeddings

# %%
def build_data(pos_file_path, neg_file_path ):
    pos_file_names = get_file_names(pos_file_path)
    neg_file_names = get_file_names(neg_file_path)
    # m is the number of training examples
    m_pos = len(pos_file_names)
    m_neg = len(neg_file_names)
    m = m_pos + m_neg
    print(m)
    pos_labels = np.ones(m_pos)
    neg_labels = np.zeros(m_neg)
    y = np.concatenate((pos_labels, neg_labels), axis=0)
    pos_data=pd.DataFrame(index=list(range(m_pos)),columns=['Review'])
    neg_data=pd.DataFrame(index=list(range(m_neg)),columns=['Review'])
    for i in range(m_pos):
        #pos_data.loc[i,'Review']=text_process(file_to_tokens(pos_file_names[i]))
        pos_data.loc[i,'Review']=file_to_tokens(pos_file_names[i])
    pos_data['Label'] = pos_labels
    for i in range(m_neg):
        #neg_data.loc[i,'Review']=text_process(file_to_tokens(neg_file_names[i]))
        neg_data.loc[i,'Review']=file_to_tokens(neg_file_names[i])
    neg_data['Label'] = neg_labels
    data=pd.concat([pos_data,neg_data],axis=0)
    data=data.sample(frac=1).reset_index(drop=True)
    return data

# %%
data_small = build_data('review_polarity_data/pos', 'review_polarity_data/neg' )
data_big_part1 = build_data ('aclImdb/train/pos','aclImdb/train/neg')
data_big_part2 = build_data ('aclImdb/test/pos','aclImdb/test/neg')
data_big = pd.concat([data_big_part1,data_big_part2],axis=0)
data_big = data_big.sample(frac=1).reset_index(drop=True)
data_huge = pd.concat([data_small,data_big],axis=0)
data_huge = data_huge.sample(frac=1).reset_index(drop=True)
# Out:
# 2000
# 25000
# 25000

# %%
len(data_huge)
# Out:
# 52000

# %%
glove_input_file = "glove.6B/glove.6B.200d.txt"
word2vec_output_file = "glove.6B/glove.6B.200d.txt.word2vec"

# %%
glove2word2vec(glove_input_file, word2vec_output_file)
# Out:
# 2019-02-09 13:01:44,264 : INFO : converting 400000 vectors from glove.6B/glove.6B.200d.txt to glove.6B/glove.6B.200d.txt.word2vec
# (400000, 200)

# %%
model = KeyedVectors.load_word2vec_format(word2vec_output_file, binary=False)
# Out:
# 2019-02-09 13:03:37,757 : INFO : loading projection weights from glove.6B/glove.6B.200d.txt.word2vec
# 2019-02-09 13:04:39,062 : INFO : loaded (400000, 200) matrix from glove.6B/glove.6B.200d.txt.word2vec

# %%
# build vocabulary and train model
model = gensim.models.Word2Vec(
    data_huge['Review'],
    size=200,
    window=10,
    min_count=2,
    workers=10)
model.train(data_huge['Review'], total_examples=len(data_huge['Review']), epochs=100)
# Out:
# 2019-02-09 13:04:48,244 : INFO : collecting all words and their counts
# 2019-02-09 13:04:48,251 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-02-09 13:04:48,676 : INFO : PROGRESS: at sentence #10000, processed 2378383 words, keeping 53076 word types
# 2019-02-09 13:04:49,065 : INFO : PROGRESS: at sentence #20000, processed 4774881 words, keeping 70564 word types
# 2019-02-09 13:04:49,450 : INFO : PROGRESS: at sentence #30000, processed 7165763 words, keeping 83559 word types
# 2019-02-09 13:04:49,839 : INFO : PROGRESS: at sentence #40000, processed 9560414 words, keeping 93886 word types
# 2019-02-09 13:04:50,221 : INFO : PROGRESS: at sentence #50000, processed 11940494 words, keeping 102827 word types
# 2019-02-09 13:04:50,307 : INFO : collected 104557 word types from a corpus of 12431273 raw words and 52000 sentences
# 2019-02-09 13:04:50,307 : INFO : Loading a fresh vocabulary
# 2019-02-09 13:04:50,473 : INFO : effective_min_count=2 retains 65356 unique words (62% of original 104557, drops 39201)
# 2019-02-09 13:04:50,474 : INFO : effective_min_count=2 leaves 12392072 word corpus (99% of original 12431273, drops 39201)
# 2019-02-09 13:04:50,904 : INFO : deleting the raw counts dictionary of 104557 items
# 2019-02-09 13:04:50,907 : INFO : sample=0.001 downsamples 45 most-common words
# 2019-02-09 13:04:50,908 : INFO : downsampling leaves estimated 9482843 word corpus (76.5% of prior 12392072)
# 2019-02-09 13:04:51,178 : INFO : estimated required memory for 65356 words and 200 dimensions: 137247600 bytes
# 2019-02-09 13:04:51,178 : INFO : resetting layer weights
# 2019-02-09 13:04:52,032 : INFO : training model with 10 workers on 65356 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2019-02-09 13:04:53,235 : INFO : EPOCH 1 - PROGRESS: at 0.08% examples, 7377 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:04:54,241 : INFO : EPOCH 1 - PROGRESS: at 8.47% examples, 394570 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:04:55,244 : INFO : EPOCH 1 - PROGRESS: at 17.09% examples, 533993 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:04:56,263 : INFO : EPOCH 1 - PROGRESS: at 25.82% examples, 607502 words/s, in_qsize 19, out_qsize 2
# 2019-02-09 13:04:57,259 : INFO : EPOCH 1 - PROGRESS: at 34.98% examples, 657754 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:04:58,273 : INFO : EPOCH 1 - PROGRESS: at 42.76% examples, 671271 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:04:59,296 : INFO : EPOCH 1 - PROGRESS: at 50.94% examples, 684192 words/s, in_qsize 20, out_qsize 6
# 2019-02-09 13:05:00,308 : INFO : EPOCH 1 - PROGRESS: at 60.23% examples, 706491 words/s, in_qsize 20, out_qsize 1
# 2019-02-09 13:05:01,311 : INFO : EPOCH 1 - PROGRESS: at 68.80% examples, 718998 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:05:02,350 : INFO : EPOCH 1 - PROGRESS: at 77.28% examples, 724368 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:05:03,359 : INFO : EPOCH 1 - PROGRESS: at 85.65% examples, 730054 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:05:04,385 : INFO : EPOCH 1 - PROGRESS: at 94.27% examples, 735025 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:05:05,027 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-02-09 13:05:05,044 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-02-09 13:05:05,049 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-02-09 13:05:05,050 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-02-09 13:05:05,052 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-02-09 13:05:05,073 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-02-09 13:05:05,143 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-09 13:05:05,145 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-09 13:05:05,148 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-09 13:05:05,151 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-09 13
words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:28:03,237 : INFO : EPOCH 95 - PROGRESS: at 58.72% examples, 685094 words/s, in_qsize 20, out_qsize 1
# 2019-02-09 13:28:04,249 : INFO : EPOCH 95 - PROGRESS: at 65.83% examples, 683638 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:28:05,253 : INFO : EPOCH 95 - PROGRESS: at 73.50% examples, 687577 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:06,283 : INFO : EPOCH 95 - PROGRESS: at 80.69% examples, 685125 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:07,295 : INFO : EPOCH 95 - PROGRESS: at 87.91% examples, 684818 words/s, in_qsize 16, out_qsize 3
# 2019-02-09 13:28:08,309 : INFO : EPOCH 95 - PROGRESS: at 95.33% examples, 684718 words/s, in_qsize 20, out_qsize 4
# 2019-02-09 13:28:08,816 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-02-09 13:28:08,824 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-02-09 13:28:08,826 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-02-09 13:28:08,857 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-02-09 13:28:08,866 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-02-09 13:28:08,868 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-02-09 13:28:08,871 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-09 13:28:08,892 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-09 13:28:08,893 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-09 13:28:08,895 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-09 13:28:08,896 : INFO : EPOCH - 95 : training on 12431273 raw words (9483557 effective words) took 13.8s, 688287 effective words/s
# 2019-02-09 13:28:09,906 : INFO : EPOCH 96 - PROGRESS: at 6.74% examples, 630193 words/s, in_qsize 17, out_qsize 2
# 2019-02-09 13:28:10,929 : INFO : EPOCH 96 - PROGRESS: at 14.46% examples, 667264 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:11,936 : INFO : EPOCH 96 - PROGRESS: at 21.76% examples, 679263 words/s, in_qsize 17, out_qsize 2
# 2019-02-09 13:28:12,955 : INFO : EPOCH 96 - PROGRESS: at 28.92% examples, 674552 words/s, in_qsize 20, out_qsize 1
# 2019-02-09 13:28:13,989 : INFO : EPOCH 96 - PROGRESS: at 36.35% examples, 675811 words/s, in_qsize 20, out_qsize 0
# 2019-02-09 13:28:15,008 : INFO : EPOCH 96 - PROGRESS: at 43.62% examples, 678224 words/s, in_qsize 18, out_qsize 3
# 2019-02-09 13:28:16,018 : INFO : EPOCH 96 - PROGRESS: at 51.00% examples, 679779 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:17,022 : INFO : EPOCH 96 - PROGRESS: at 58.64% examples, 683880 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:18,071 : INFO : EPOCH 96 - PROGRESS: at 65.93% examples, 681404 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:19,090 : INFO : EPOCH 96 - PROGRESS: at 73.58% examples, 684568 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:28:20,096 : INFO : EPOCH 96 - PROGRESS: at 80.94% examples, 685227 words/s, in_qsize 20, out_qsize 1
# 2019-02-09 13:28:21,099 : INFO : EPOCH 96 - PROGRESS: at 88.00% examples, 684227 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:28:22,100 : INFO : EPOCH 96 - PROGRESS: at 95.49% examples, 685036 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:22,638 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-02-09 13:28:22,663 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-02-09 13:28:22,672 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-02-09 13:28:22,674 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-02-09 13:28:22,680 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-02-09 13:28:22,696 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-02-09 13:28:22,706 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-09 13:28:22,715 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-09 13:28:22,719 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-09 13:28:22,729 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-09 13:28:22,730 : INFO : EPOCH - 96 : training on 12431273 raw words (9482838 effective words) took 13.8s, 685652 effective words/s
# 2019-02-09 13:28:23,746 : INFO : EPOCH 97 - PROGRESS: at 7.25% examples, 671961 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:28:24,762 : INFO : EPOCH 97 - PROGRESS: at 14.45% examples, 667870 words/s, in_qsize 17, out_qsize 2
# 2019-02-09 13:28:25,775 : INFO : EPOCH 97 - PROGRESS: at 21.85% examples, 680763 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:26,786 : INFO : EPOCH 97 - PROGRESS: at 29.02% examples, 677078 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:27,795 : INFO : EPOCH 97 - PROGRESS: at 36.44% examples, 681213 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:28:28,813 : INFO : EPOCH 97 - PROGRESS: at 43.76% examples, 684106 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:29,817 : INFO : EPOCH 97 - PROGRESS: at 51.21% examples, 686247 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13
words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:28:57,523 : INFO : EPOCH 99 - PROGRESS: at 50.38% examples, 671731 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:28:58,534 : INFO : EPOCH 99 - PROGRESS: at 57.17% examples, 666137 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:28:59,541 : INFO : EPOCH 99 - PROGRESS: at 64.12% examples, 665528 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:29:00,586 : INFO : EPOCH 99 - PROGRESS: at 71.56% examples, 667095 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:29:01,612 : INFO : EPOCH 99 - PROGRESS: at 78.59% examples, 664768 words/s, in_qsize 15, out_qsize 4
# 2019-02-09 13:29:02,637 : INFO : EPOCH 99 - PROGRESS: at 86.21% examples, 668528 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:29:03,655 : INFO : EPOCH 99 - PROGRESS: at 92.96% examples, 664716 words/s, in_qsize 20, out_qsize 1
# 2019-02-09 13:29:04,495 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-02-09 13:29:04,497 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-02-09 13:29:04,521 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-02-09 13:29:04,522 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-02-09 13:29:04,529 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-02-09 13:29:04,533 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-02-09 13:29:04,542 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-09 13:29:04,550 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-09 13:29:04,566 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-09 13:29:04,569 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-09 13:29:04,569 : INFO : EPOCH - 99 : training on 12431273 raw words (9483245 effective words) took 14.2s, 669716 effective words/s
# 2019-02-09 13:29:05,613 : INFO : EPOCH 100 - PROGRESS: at 7.32% examples, 660678 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:29:06,616 : INFO : EPOCH 100 - PROGRESS: at 14.53% examples, 666311 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:29:07,638 : INFO : EPOCH 100 - PROGRESS: at 21.69% examples, 670472 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:29:08,645 : INFO : EPOCH 100 - PROGRESS: at 29.29% examples, 679043 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:29:09,671 : INFO : EPOCH 100 - PROGRESS: at 36.43% examples, 676176 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:29:10,673 : INFO : EPOCH 100 - PROGRESS: at 43.84% examples, 682868 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:29:11,674 : INFO : EPOCH 100 - PROGRESS: at 51.36% examples, 686496 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:29:12,696 : INFO : EPOCH 100 - PROGRESS: at 58.55% examples, 682863 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:29:13,717 : INFO : EPOCH 100 - PROGRESS: at 65.36% examples, 677677 words/s, in_qsize 20, out_qsize 2
# 2019-02-09 13:29:14,733 : INFO : EPOCH 100 - PROGRESS: at 72.45% examples, 676203 words/s, in_qsize 18, out_qsize 1
# 2019-02-09 13:29:15,751 : INFO : EPOCH 100 - PROGRESS: at 79.69% examples, 675593 words/s, in_qsize 19, out_qsize 1
# 2019-02-09 13:29:16,770 : INFO : EPOCH 100 - PROGRESS: at 87.36% examples, 679400 words/s, in_qsize 20, out_qsize 0
# 2019-02-09 13:29:17,778 : INFO : EPOCH 100 - PROGRESS: at 94.93% examples, 680824 words/s, in_qsize 19, out_qsize 0
# 2019-02-09 13:29:18,425 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-02-09 13:29:18,429 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-02-09 13:29:18,453 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-02-09 13:29:18,454 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-02-09 13:29:18,456 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-02-09 13:29:18,464 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-02-09 13:29:18,466 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-02-09 13:29:18,472 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-09 13:29:18,473 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-09 13:29:18,481 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-09 13:29:18,481 : INFO : EPOCH - 100 : training on 12431273 raw words (9482549 effective words) took 13.9s, 681799 effective words/s
# 2019-02-09 13:29:18,482 : INFO : training on a 1243127300 raw words (948286097 effective words) took 1395.1s, 679713 effective words/s
# (948286097, 1243127300)

# %%
model.save("enhanced_glove.model")
# Out:
# 2019-02-09 13:32:24,873 : INFO : saving Word2Vec object under enhanced_glove.model, separately None
# 2019-02-09 13:32:24,889 : INFO : storing np array 'vectors' to enhanced_glove.model.wv.vectors.npy
# 2019-02-09 13:32:25,385 : INFO : not storing attribute vectors_norm
# 2019-02-09 13:32:25,390 : INFO : storing np array 'syn1neg' to enhanced_glove.model.trainables.syn1neg.npy
# 2019-02-09 13:32:26,030 : INFO : not storing attribute cum_table
# 2019-02-09 13:32:26,356 : INFO : saved enhanced_glove.model

# %%
model = Word2Vec.load("enhanced_glove.model")
# Out:
# 2019-02-09 13:32:43,664 : INFO : loading Word2Vec object from enhanced_glove.model
# 2019-02-09 13:32:43,790 : INFO : loading wv recursively from enhanced_glove.model.wv.* with mmap=None
# 2019-02-09 13:32:43,792 : INFO : loading vectors from enhanced_glove.model.wv.vectors.npy with mmap=None
# 2019-02-09 13:32:43,851 : INFO : setting ignored attribute vectors_norm to None
# 2019-02-09 13:32:43,852 : INFO : loading vocabulary recursively from enhanced_glove.model.vocabulary.* with mmap=None
# 2019-02-09 13:32:43,853 : INFO : loading trainables recursively from enhanced_glove.model.trainables.* with mmap=None
# 2019-02-09 13:32:43,854 : INFO : loading syn1neg from enhanced_glove.model.trainables.syn1neg.npy with mmap=None
# 2019-02-09 13:32:43,881 : INFO : setting ignored attribute cum_table to None
# 2019-02-09 13:32:43,882 : INFO : loaded enhanced_glove.model

# %% [markdown]
# ## NLP_Task : now let's use our pretrained word embedding to accomplish our task

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier,BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression,RidgeClassifier,Lasso
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
import xgboost as xgb
from sklearn.model_selection import ShuffleSplit, GridSearchCV
from sklearn.metrics import make_scorer,f1_score, auc, roc_auc_score

# %%
w2v = dict(zip(model.wv.index2word, model.wv.syn0))
# Out:
# /home/ahmedbahgat/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   """Entry point for launching an IPython kernel.

# %%
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        # if a text is empty we should return a vector of zeros
        # with the same dimensionality as all the other vectors
        self.dim = len(word2vec.values())

    def fit(self, X, y):
        return self

    def transform(self, X):
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(self.dim)], axis=0)
            for words in X
        ])

# %%
data_huge_train, data_huge_test, label_huge_train, label_huge_test = \
train_test_split(data_huge['Review'], data_huge['Label'], test_size=0.2, random_state = 0)
print(len(data_huge_train), len(data_huge_test), len(data_huge_train) + len(data_huge_test))
# Out:
# 41600 10400 52000

# %%
pipeline1 = Pipeline([
    ("word2vec vectorizer", MeanEmbeddingVectorizer(w2v)),  # strings to token integer counts
    ('classifier', RidgeClassifier(random_state=0))
    #('classifier', xgb.XGBClassifier(random_state=0))
])

# %%
pipeline1.fit(data_huge_train,label_huge_train)
# Out:
# Pipeline(memory=None,
#      steps=[('word2vec vectorizer', <__main__.MeanEmbeddingVectorizer object at 0x7f734e7617f0>), ('classifier', RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=0, solver='auto',
#         tol=0.001))])

# %%
predictions1 = pipeline1.predict(data_huge_test)

# %%
print(roc_auc_score(predictions1,label_huge_test))
# Out:
# 0.8839663119148804

# %%
print(classification_report(predictions1,label_huge_test))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.87      0.89      0.88      5129
#         1.0       0.89      0.88      0.88      5271
#
# avg / total       0.88      0.88      0.88     10400
